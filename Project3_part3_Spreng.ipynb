# %% [markdown]
# # Create Project

# %%
#import libraries and SQL 
import pandas as pd

# import SQL materials
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists
import pymysql
pymysql.install_as_MySQLdb()
from urllib.parse import quote_plus as urlquote
from sqlalchemy_utils import create_database, database_exists

# %%
## Change username and password to match your personal MySQL Server settings
username = "root"
password = "Ahimsa81981182!"

movie = f'mysql+pymysql://{username}:{password}@localhost/project3'
engine = create_engine(movie)

# %%
# Check if the database exists. If not, create it.
if database_exists(movie) == False:
  create_database(movie)
else:
  print('The database already exists!')

# %%
#load the data
tmbd=pd.read_csv('Data4_March31/tmdb_results_combined.csv.gz')
#check that the data loaded
tmbd.head(2)
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
#
#         id original_language   original_title  ... revenue  runtime  \
# 0      NaN               NaN              NaN  ...     NaN      NaN
# 1  62127.0                en  The Fantasticks  ...     0.0     86.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                          tagline            title  video  \
# 0                                            NaN              NaN    NaN
# 1  Try to remember the first time magic happened  The Fantasticks    0.0
#
#    vote_average vote_count certification
# 0           NaN        NaN           NaN
# 1           5.5       22.0           NaN
#
# [2 rows x 26 columns]

# %%
tmbd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2544 entries, 0 to 2543
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2544 non-null   object
#  1   adult                  2542 non-null   float64
#  2   backdrop_path          1369 non-null   object
#  3   belongs_to_collection  204 non-null    object
#  4   budget                 2542 non-null   float64
#  5   genres                 2542 non-null   object
#  6   homepage               171 non-null    object
#  7   id                     2542 non-null   float64
#  8   original_language      2542 non-null   object
#  9   original_title         2542 non-null   object
#  10  overview               2492 non-null   object
#  11  popularity             2542 non-null   float64
#  12  poster_path            2284 non-null   object
#  13  production_companies   2542 non-null   object
#  14  production_countries   2542 non-null   object
#  15  release_date           2525 non-null   object
#  16  revenue                2542 non-null   float64
#  17  runtime                2542 non-null   float64
#  18  spoken_languages       2542 non-null   object
#  19  status                 2542 non-null   object
#  20  tagline                1088 non-null   object
#  21  title                  2542 non-null   object
#  22  video                  2542 non-null   float64
#  23  vote_average           2542 non-null   float64
#  24  vote_count             2542 non-null   float64
#  25  certification          807 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 516.9+ KB

# %%
# load the  cleaned data
basics = pd.read_csv('Data/title_basics.csv.gz')
aka = pd.read_csv('Data/title_aka.csv.gz')
rating = pd.read_csv('Data/title_rating.csv.gz')

# %%
## create a col with a list of genres
basics['genres_split'] = basics['genres'].str.split(',')
basics
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0096056     movie                               Crime and Punishment
# ...          ...       ...                                                ...
# 81404  tt9914942     movie                             Life Without Sara Amat
# 81405  tt9915872     movie                               The Last White Witch
# 81406  tt9916170     movie                                      The Rehearsal
# 81407  tt9916190     movie                                          Safeguard
# 81408  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0     2001.0      NaN
# 1      El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                     The Other Side of the Wind        0     2018.0      NaN
# 3                              The Naked Monster        0     2005.0      NaN
# 4                           Crime and Punishment        0     2002.0      NaN
# ...                                          ...      ...        ...      ...
# 81404                 La vida sense la Sara Amat        0     2019.0      NaN
# 81405                  My Girlfriend is a Wizard        0     2019.0      NaN
# 81406                                   O Ensaio        0     2019.0      NaN
# 81407                                  Safeguard        0     2020.0      NaN
# 81408                                   Akelarre        0     2020.0      NaN
#
#        runtimeMinutes                     genres  \
# 0                 118     Comedy,Fantasy,Romance
# 1                  70                      Drama
# 2                 122                      Drama
# 3                 100       Comedy,Horror,Sci-Fi
# 4                 126                      Drama
# ...               ...                        ...
# 81404              74                      Drama
# 81405              97       Comedy,Drama,Fantasy
# 81406              51                      Drama
# 81407              95  Action,Adventure,Thriller
# 81408              92              Drama,History
#
#                         genres_split
# 0         [Comedy, Fantasy, Romance]
# 1                            [Drama]
# 2                            [Drama]
# 3           [Comedy, Horror, Sci-Fi]
# 4                            [Drama]
# ...                              ...
# 81404                        [Drama]
# 81405       [Comedy, Drama, Fantasy]
# 81406                        [Drama]
# 81407  [Action, Adventure, Thriller]
# 81408               [Drama, History]
#
# [81409 rows x 10 columns]

# %%
# explode genres
exploded_genres = basics.explode('genres_split')
exploded_genres
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# ...          ...       ...                                                ...
# 81407  tt9916190     movie                                          Safeguard
# 81407  tt9916190     movie                                          Safeguard
# 81407  tt9916190     movie                                          Safeguard
# 81408  tt9916362     movie                                              Coven
# 81408  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0     2001.0      NaN
# 0                                 Kate & Leopold        0     2001.0      NaN
# 0                                 Kate & Leopold        0     2001.0      NaN
# 1      El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                     The Other Side of the Wind        0     2018.0      NaN
# ...                                          ...      ...        ...      ...
# 81407                                  Safeguard        0     2020.0      NaN
# 81407                                  Safeguard        0     2020.0      NaN
# 81407                                  Safeguard        0     2020.0      NaN
# 81408                                   Akelarre        0     2020.0      NaN
# 81408                                   Akelarre        0     2020.0      NaN
#
#        runtimeMinutes                     genres genres_split
# 0                 118     Comedy,Fantasy,Romance       Comedy
# 0                 118     Comedy,Fantasy,Romance      Fantasy
# 0                 118     Comedy,Fantasy,Romance      Romance
# 1                  70                      Drama        Drama
# 2                 122                      Drama        Drama
# ...               ...                        ...          ...
# 81407              95  Action,Adventure,Thriller       Action
# 81407              95  Action,Adventure,Thriller    Adventure
# 81407              95  Action,Adventure,Thriller     Thriller
# 81408              92              Drama,History        Drama
# 81408              92              Drama,History      History
#
# [152476 rows x 10 columns]

# %%
genres_split =basics['genres'].str.split(',')

unique_genres=genres_split.explode().unique()
unique_genres
# Out:
# array(['Comedy', 'Fantasy', 'Romance', 'Drama', 'Horror', 'Sci-Fi',
#        'Biography', 'Mystery', 'Musical', 'Action', 'Adventure', 'Crime',
#        'Thriller', 'Music', 'Animation', 'Family', 'History', 'War',
#        'Sport', 'Western', 'Adult', 'Short', 'Reality-TV', 'News',
#        'Talk-Show', 'Game-Show'], dtype=object)

# %%
#use unique to get the genres from the genres_split
unique_genres = sorted(exploded_genres['genres_split'].unique())

# %%
#create the genres_split column
title_genres = exploded_genres[['tconst', 'genres_split']].copy() 
title_genres.head(10)
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama
# 3  tt0088751       Comedy
# 3  tt0088751       Horror
# 3  tt0088751       Sci-Fi
# 4  tt0096056        Drama
# 5  tt0100275       Comedy

# %%
## Making the genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
basics['genres_split']
# Out:
# 0           [Comedy, Fantasy, Romance]
# 1                              [Drama]
# 2                              [Drama]
# 3             [Comedy, Horror, Sci-Fi]
# 4                              [Drama]
#                      ...
# 81404                          [Drama]
# 81405         [Comedy, Drama, Fantasy]
# 81406                          [Drama]
# 81407    [Action, Adventure, Thriller]
# 81408                 [Drama, History]
# Name: genres_split, Length: 81409, dtype: object

# %%
# create a new genre_id column using the map and drop string genres
basics['genre_id'] = basics['genres_split'].map(genre_map)
basics = basics.drop(columns='genres_split')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [34], line 2
#       1 # create a new genre_id column using the map and drop string genres
# ----> 2 basics['genre_id'] = basics['genres_split'].map(genre_map)
#       3 basics = basics.drop(columns='genres_split')
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\series.py:4539, in Series.map(self, arg, na_action)
#    4460 def map(
#    4461     self,
#    4462     arg: Callable | Mapping | Series,
#    4463     na_action: Literal["ignore"] | None = None,
#    4464 ) -> Series:
#    4465     """
#    4466     Map values of Series according to an input mapping or function.
#    4467
#    (...)
#    4537     dtype: object
#    4538     """
# -> 4539     new_values = self._map_values(arg, na_action=na_action)
#    4540     return self._constructor(new_values, index=self.index).__finalize__(
#    4541         self, method="map"
#    4542     )
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\base.py:862, in IndexOpsMixin._map_values(self, mapper, na_action)
#     858     return cat.map(mapper)
#     860 values = self._values
# --> 862 indexer = mapper.index.get_indexer(values)
#     863 new_values = algorithms.take_nd(mapper._values, indexer)
#     865 return new_values
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\indexes\base.py:3974, in Index.get_indexer(self, target, method, limit, tolerance)
#    3969     target = target.astype(dtype, copy=False)
#    3970     return this._get_indexer(
#    3971         target, method=method, limit=limit, tolerance=tolerance
#    3972     )
# -> 3974 return self._get_indexer(target, method, limit, tolerance)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\indexes\base.py:4001, in Index._get_indexer(self, target, method, limit, tolerance)
#    3998     else:
#    3999         tgt_values = target._get_engine_target()
# -> 4001     indexer = self._engine.get_indexer(tgt_values)
#    4003 return ensure_platform_int(indexer)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\_libs\index.pyx:308, in pandas._libs.index.IndexEngine.get_indexer()
#
# File pandas\_libs\hashtable_class_helper.pxi:5794, in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# TypeError: unhashable type: 'list'
